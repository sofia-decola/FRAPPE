# %% [markdown]
# # Rhythmic Period Analysis (RPA)
#
# ---
#
# Proteomics Data Analysis Package FRAPPE: Framework for Rhythmic Analysis of Preliminary Proteomics Experiments
# Tools to analyze the rhythmic stability of the proteome through period length changes

# %%
import rhythmic_period_analysis as rpa

# %% [markdown]
# Specific circadian adaptation of rhythmic period analysis, including an export of lists of protein names and whether they maintain circadian rhythmicity, lose circadian rhythmicity, or gain circadian rhythmicity. Lower bound is 18 hours and upper bound is 26 hours

# %% [markdown]
# ###Example Usage/Tutorial

# %% [markdown]
# Rhythmic Period Analysis (RPA)
#
# Example where proteins are being checked if they are between 20 and 24 hours in length for period, and datasets came from ECHO, so default column names are used

# %%
csv1 = "Control_Group_Data.csv"
csv2 = "Experimental_Group_Data.csv"
#rpa.rpa(csv1, csv2, "Control Group", "Exp Group", lower_bound=20, upper_bound=24, output="RPA_output")

# %% [markdown]
# Circadian Comparison
#
# Example where datasets are not from ECHO

# %%
csv1 = "/Users/sofiadecola/Senior Thesis/Thesis Data/female intersect/FDSAD_ECHO_INTERSECT.csv" #control
csv2 = "/Users/sofiadecola/Senior Thesis/Thesis Data/female intersect/FSWAD_ECHO_INTERSECT.csv" # exp group
rpa.rpa(csv1, csv2, "FDSAD", "FSWAD", 26, 18)
# Specifying column names allows for flexibility outside of ECHO datasets
# Out:
#        Gene Name  Period_FDSAD  Period_FSWAD  FDSAD Within Bound  \
# 0     A0A087WP33     27.000000     20.398183               False
# 1     A0A087WQ44     19.180325     20.399141                True
# 2     A0A087WQH8     12.500370     27.000000               False
# 3     A0A087WSP5     17.917781     19.009252               False
# 4     A0A0A6YY83     18.660295     18.049478                True
# ...          ...           ...           ...                 ...
# 5131      Q9Z2Z6     10.573354      9.781697               False
# 5132      Q9Z315     26.910631     10.180271               False
# 5133      Q9Z321     22.553009     22.500008                True
# 5134      Q9Z329     20.493602     21.760791                True
# 5135      S4R1W5     12.683104     27.000000               False
#
#       FSWAD Within Bound
# 0                   True
# 1                   True
# 2                  False
# 3                   True
# 4                   True
# ...                  ...
# ...

# %%
csv1 = "/Users/sofiadecola/Senior Thesis/Thesis Data/female intersect/FDSLM_ECHO_INTERSECT.csv" #control
csv2 = "/Users/sofiadecola/Senior Thesis/Thesis Data/female intersect/FSWLM_ECHO_INTERSECT.csv" # exp group
rpa.rpa(csv1, csv2, "FDSLM", "FSWLM", 26, 18)
# Specifying column names allows for flexibility outside of ECHO datasets
# Out:
#        Gene Name  Period_FDSLM  Period_FSWLM  FDSLM Within Bound  \
# 0     A0A087WP33     26.977235      9.887540               False
# 1     A0A087WQ44     10.366393     17.746548               False
# 2     A0A087WQH8     27.000000     10.739384               False
# 3     A0A087WSP5     25.585097     20.653543                True
# 4     A0A0A6YY83     22.714454      9.866149                True
# ...          ...           ...           ...                 ...
# 5131      Q9Z2Z6     14.779695     10.779242               False
# 5132      Q9Z315     10.220929     27.000000               False
# 5133      Q9Z321     27.000000     23.024272               False
# 5134      Q9Z329     20.704773     20.558760                True
# 5135      S4R1W5     19.765733     23.411231                True
#
#       FSWLM Within Bound
# 0                  False
# 1                  False
# 2                  False
# 3                   True
# 4                  False
# ...                  ...
# ...
